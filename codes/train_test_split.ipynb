# %% [markdown]
# # Part1: Split data into training, validation and test set manually

# %% [markdown]
# Codes below are used to split Expedia data into training, validation and test set.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

from scipy.stats import skew
from sklearn.model_selection import train_test_split

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
print('training data has %d records'%len(train))
print('test data has %d records'%len(test))
# Out:
# training data has 9917530 records
# test data has 6622629 records

# %%
cols_train_only = [col for col in train.columns.unique().tolist() if col not in test.columns.unique().tolist()]
print('Columns only available in training data:',cols_train_only)
# Out:
# Columns only available in training data: ['position', 'click_bool', 'gross_bookings_usd', 'booking_bool']

# %%
train = train.drop(columns = cols_train_only)
train.head()
# Out:
#    srch_id            date_time  site_id  visitor_location_country_id  \
# 0        1  2013-04-04 08:32:15       12                          187
# 1        1  2013-04-04 08:32:15       12                          187
# 2        1  2013-04-04 08:32:15       12                          187
# 3        1  2013-04-04 08:32:15       12                          187
# 4        1  2013-04-04 08:32:15       12                          187
#
#    visitor_hist_starrating  visitor_hist_adr_usd  prop_country_id  prop_id  \
# 0                      NaN                   NaN              219      893
# 1                      NaN                   NaN              219    10404
# 2                      NaN                   NaN              219    21315
# 3                      NaN                   NaN              219    27348
# 4                      NaN                   NaN              219    29604
#
#    prop_starrating  prop_review_score           ...             \
# 0                3                3.5           ...
# 1                4                4.0           ...
# 2                3                4.5           ...
# 3                2                4.0           ...
# 4                4                3.5           ...
#
#    comp5_rate_percent_diff  comp6_rate  comp6_inv  comp6_rate_percent_diff  \
# 0                      NaN         NaN        NaN                      NaN
# 1                      NaN         NaN        NaN                      NaN
# 2                      NaN         NaN        NaN                      NaN
# 3                      NaN         NaN        NaN                      NaN
# 4                      NaN         NaN        NaN                      NaN
#
#    comp7_rate  comp7_inv  comp7_rate_percent_diff  comp8_rate  comp8_inv  \
# 0         NaN        NaN                      NaN         0.0        0.0
# 1         NaN        NaN                      NaN         0.0        0.0
# 2         NaN        NaN                      NaN         0.0        0.0
# 3         NaN        NaN                      NaN        -1.0        0.0
# 4         NaN        NaN                      NaN         0.0        0.0
#
#    comp8_rate_percent_diff
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      5.0
# 4                      NaN
#
# [5 rows x 50 columns]

# %%
# combine train and test data
all_data = pd.concat([train, test], ignore_index=True)
all_data.head()
# Out:
#    srch_id            date_time  site_id  visitor_location_country_id  \
# 0        1  2013-04-04 08:32:15       12                          187
# 1        1  2013-04-04 08:32:15       12                          187
# 2        1  2013-04-04 08:32:15       12                          187
# 3        1  2013-04-04 08:32:15       12                          187
# 4        1  2013-04-04 08:32:15       12                          187
#
#    visitor_hist_starrating  visitor_hist_adr_usd  prop_country_id  prop_id  \
# 0                      NaN                   NaN              219      893
# 1                      NaN                   NaN              219    10404
# 2                      NaN                   NaN              219    21315
# 3                      NaN                   NaN              219    27348
# 4                      NaN                   NaN              219    29604
#
#    prop_starrating  prop_review_score           ...             \
# 0                3                3.5           ...
# 1                4                4.0           ...
# 2                3                4.5           ...
# 3                2                4.0           ...
# 4                4                3.5           ...
#
#    comp5_rate_percent_diff  comp6_rate  comp6_inv  comp6_rate_percent_diff  \
# 0                      NaN         NaN        NaN                      NaN
# 1                      NaN         NaN        NaN                      NaN
# 2                      NaN         NaN        NaN                      NaN
# 3                      NaN         NaN        NaN                      NaN
# 4                      NaN         NaN        NaN                      NaN
#
#    comp7_rate  comp7_inv  comp7_rate_percent_diff  comp8_rate  comp8_inv  \
# 0         NaN        NaN                      NaN         0.0        0.0
# 1         NaN        NaN                      NaN         0.0        0.0
# 2         NaN        NaN                      NaN         0.0        0.0
# 3         NaN        NaN                      NaN        -1.0        0.0
# 4         NaN        NaN                      NaN         0.0        0.0
#
#    comp8_rate_percent_diff
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      5.0
# 4                      NaN
#
# [5 rows x 50 columns]

# %%
print('Whole dataset has %d records' % len(all_data))
# Out:
# Whole dataset has 16540159 records

# %%
# clean date_time feature
def clean_date_time(df):
    '''
    this function takes in a dataframe, and output a dataframe with clean resp time.
    input: data frame;
    output: data frame with nice-formatted resp_time
    '''
    df['date_time'] = pd.to_datetime(df.date_time)
    df.sort_values(by=['date_time'],inplace=True)
    df.date_time = df.date_time.astype('str')
    df.date_time = df.date_time.apply(get_date)    
    df = df.groupby('date_time').mean()
    df = df.reset_index()
    return df


all_data['date_time'] = pd.to_datetime(all_data.date_time)
all_data.sort_values(by=['date_time'],inplace=True)

# %%
all_data_ = all_data.drop(columns=['index','level_0'])
all_data_.head()
# Out:
#    srch_id           date_time  site_id  visitor_location_country_id  \
# 0   365278 2012-11-01 00:01:37       24                          216
# 1   365278 2012-11-01 00:01:37       24                          216
# 2   365278 2012-11-01 00:01:37       24                          216
# 3   365278 2012-11-01 00:01:37       24                          216
# 4   365278 2012-11-01 00:01:37       24                          216
#
#    visitor_hist_starrating  visitor_hist_adr_usd  prop_country_id  prop_id  \
# 0                      NaN                   NaN              225    24202
# 1                      NaN                   NaN              225      327
# 2                      NaN                   NaN              225    20797
# 3                      NaN                   NaN              225    53733
# 4                      NaN                   NaN              225    57269
#
#    prop_starrating  prop_review_score           ...             \
# 0                3                0.0           ...
# 1                4                4.5           ...
# 2                3                3.0           ...
# 3                3                3.0           ...
# 4                4                4.5           ...
#
#    comp5_rate_percent_diff  comp6_rate  comp6_inv  comp6_rate_percent_diff  \
# 0                      NaN         NaN        NaN                      NaN
# 1                      7.0         NaN        NaN                      NaN
# 2                      NaN         NaN        NaN                      NaN
# 3                      NaN         NaN        NaN                      NaN
# 4                      2.0         NaN        NaN                      NaN
#
#    comp7_rate  comp7_inv  comp7_rate_percent_diff  comp8_rate  comp8_inv  \
# 0         NaN        NaN                      NaN         NaN        NaN
# 1         NaN        NaN                      NaN         NaN        NaN
# 2         NaN        NaN                      NaN         NaN        NaN
# 3         NaN        NaN                      NaN         NaN        NaN
# 4         NaN        NaN                      NaN         NaN        NaN
#
#    comp8_rate_percent_diff
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
#
# [5 rows x 50 columns]

# %% [markdown]
# For manually splitting dataset, I first split whole dataset into training(0.8) and test set(0.2), then within training set I further split it into training set(0.8) and validation set (0.2).

# %%
# Approach1: split data manually
training_data = all_data_[0: 10585701]
validation_data = all_data_[10585701:13232127]
test_data = all_data_[13232127:16540160]

# %%
print('training set has %d records'%len(training_data))
print('validation set has %d records'%len(validation_data))
print('test set has %d records'%len(test_data))
# Out:
# training set has 10585701 records
# validation set has 2646426 records
# test set has 3308032 records

# %%
training_data.to_csv('training_set_manually.csv',encoding = 'utf-8',index = False)
# validation_data.to_csv('validation_set_manually.csv',encoding = 'utf-8',index = False)
# test_data.to_csv('test_set_manually.csv',encoding = 'utf-8',index = False)

# %% [markdown]
# reference: https://stats.stackexchange.com/questions/101066/split-train-validation-test-sets-by-time-is-it-correct

# %%
# Approach2: timeseries split
from sklearn.model_selection import TimeSeriesSplit

features = [col for col in all_data_.columns.unique().tolist() if col != 'price_usd']
target = ['price_usd']

X = all_data_[features]
y = all_data_[target]

tscv = TimeSeriesSplit(n_splits=5)
# Out:
# <generator object TimeSeriesSplit.split at 0x10c0ce1a8>

# %%
for train_index, test_index in tscv.split(X,y):
    print("TRAIN:", train_index, "TEST:", test_index)    
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    # TODO: build model
    # TODO: evaluate accuracy
# Out:
# TRAIN: [      0       1       2 ... 2756691 2756692 2756693] TEST: [2756694 2756695 2756696 ... 5513384 5513385 5513386]
# TRAIN: [      0       1       2 ... 5513384 5513385 5513386] TEST: [5513387 5513388 5513389 ... 8270077 8270078 8270079]
# TRAIN: [      0       1       2 ... 8270077 8270078 8270079] TEST: [ 8270080  8270081  8270082 ... 11026770 11026771 11026772]
# TRAIN: [       0        1        2 ... 11026770 11026771 11026772] TEST: [11026773 11026774 11026775 ... 13783463 13783464 13783465]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-fbc32fdf6ab6> in <module>()
#       1 for train_index, test_index in tscv.split(X,y):
#       2     print("TRAIN:", train_index, "TEST:", test_index)
# ----> 3     X_train = X.iloc[train_index]
#       4     X_test = X.iloc[test_index]
#       5
#
# /anaconda3/envs/leetcode/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# /anaconda3/envs/leetcode/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2089         # a list of integers
#    2090         elif is_list_like_indexer(key):
# -> 2091             return self._get_list_axis(key, axis=axis)
#    2092
#    2093         # a single integer
#
# /anaconda3/envs/leetcode/lib/python3.6/site-packages/pandas/core/indexing.py in _get_list_axis(self, key, axis)
#    2068             axis = self.axis or 0
#    2069         try:
# -> 2070             return self.obj._take(key, axis=axis)
#    2071         except IndexError:
#    2072             # re-raise with different error message
#
# /anaconda3/envs/leetcode/lib/python3.6/site-packages/pandas/core/generic.py in _take(self, indices, axis, is_copy)
#    2787         new_data = self._data.take(indices,
#    2788                                    axis=self._get_block_manager_axis(axis),
# -> 2789                                    verify=True)
#    2790         result = self._constructor(new_data).__finalize__(self)
#    2791
#
# /anaconda3/envs/leetcode/lib/python3.6/site-packages/pandas/core/internals.py in take(self, indexer, axis, verify, convert)
#    4537         new_labels = self.axes[axis].take(indexer)
#    4538         return self.reindex_indexer(new_axis=new_labels, indexer=indexer,
# -> 4539                                     axis=axis, allow_dups=True)
#    4540
#    4541     def merge(self, other, lsuffix='', rsuffix=''):
#
# /anaconda3/envs/leetcode/lib/python3.6/site-packages/pandas/core/internals.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    4423             new_blocks = [blk.take_nd(indexer, axis=axis, fill_tuple=(
#    4424                 fill_value if fill_value is not None else blk.fill_value,))
# -> 4425                 for blk in self.blocks]
#    4426
#    4427         new_axes = list(self.axes)
#
# /anaconda3/envs/leetcode/lib/python3.6/site-packages/pandas/core/internals.py in <listcomp>(.0)
#    4423             new_blocks = [blk.take_nd(indexer, axis=axis, fill_tuple=(
#    4424                 fill_value if fill_value is not None else blk.fill_value,))
# -> 4425                 for blk in self.blocks]
#    4426
#    4427         new_axes = list(self.axes)
#
# /anaconda3/envs/leetcode/lib/python3.6/site-packages/pandas/core/internals.py in take_nd(self, indexer, axis, new_mgr_locs, fill_tuple)
#    1256             fill_value = fill_tuple[0]
#    1257             new_values = algos.take_nd(values, indexer, axis=axis,
# -> 1258                                        allow_fill=True, fill_value=fill_value)
#    1259
#    1260         if new_mgr_locs is None:
#
# /anaconda3/envs/leetcode/lib/python3.6/site-packages/pandas/core/algorithms.py in take_nd(arr, indexer, axis, out, fill_value, mask_info, allow_fill)
#    1657     func = _get_take_nd_function(arr.ndim, arr.dtype, out.dtype, axis=axis,
#    1658                                  mask_info=mask_info)
# -> 1659     func(arr, indexer, out, fill_value)
#    1660
#    1661     if flip_order:
#
# /anaconda3/envs/leetcode/lib/python3.6/site-packages/pandas/core/algorithms.py in wrapper(arr, indexer, out, fill_value)
#    1259         if fill_wrap is not None:
#    1260             fill_value = fill_wrap(fill_value)
# -> 1261         f(arr, indexer, out, fill_value=fill_value)
#    1262
#    1263     return wrapper
#
# KeyboardInterrupt:
