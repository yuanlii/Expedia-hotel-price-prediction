# %% [markdown]
# # Resampling time-series

# %% [markdown]
# <h3> Prepare data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

from scipy.stats import skew
from sklearn.model_selection import train_test_split

# %%
train = pd.read_csv('../expedia_data/train.csv')
test = pd.read_csv('../expedia_data/test.csv')

# %%
print('training data has %d records'%len(train))
print('test data has %d records'%len(test))
# Out:
# training data has 9917530 records
# test data has 6622629 records

# %%
cols_train_only = [col for col in train.columns.unique().tolist() if col not in test.columns.unique().tolist()]
print('Columns only available in training data:',cols_train_only)
# Out:
# Columns only available in training data: ['position', 'click_bool', 'gross_bookings_usd', 'booking_bool']

# %%
train = train.drop(columns = cols_train_only)
train.head()
# Out:
#    srch_id            date_time  site_id  visitor_location_country_id  \
# 0        1  2013-04-04 08:32:15       12                          187
# 1        1  2013-04-04 08:32:15       12                          187
# 2        1  2013-04-04 08:32:15       12                          187
# 3        1  2013-04-04 08:32:15       12                          187
# 4        1  2013-04-04 08:32:15       12                          187
#
#    visitor_hist_starrating  visitor_hist_adr_usd  prop_country_id  prop_id  \
# 0                      NaN                   NaN              219      893
# 1                      NaN                   NaN              219    10404
# 2                      NaN                   NaN              219    21315
# 3                      NaN                   NaN              219    27348
# 4                      NaN                   NaN              219    29604
#
#    prop_starrating  prop_review_score           ...             \
# 0                3                3.5           ...
# 1                4                4.0           ...
# 2                3                4.5           ...
# 3                2                4.0           ...
# 4                4                3.5           ...
#
#    comp5_rate_percent_diff  comp6_rate  comp6_inv  comp6_rate_percent_diff  \
# 0                      NaN         NaN        NaN                      NaN
# 1                      NaN         NaN        NaN                      NaN
# 2                      NaN         NaN        NaN                      NaN
# 3                      NaN         NaN        NaN                      NaN
# 4                      NaN         NaN        NaN                      NaN
#
#    comp7_rate  comp7_inv  comp7_rate_percent_diff  comp8_rate  comp8_inv  \
# 0         NaN        NaN                      NaN         0.0        0.0
# 1         NaN        NaN                      NaN         0.0        0.0
# 2         NaN        NaN                      NaN         0.0        0.0
# 3         NaN        NaN                      NaN        -1.0        0.0
# 4         NaN        NaN                      NaN         0.0        0.0
#
#    comp8_rate_percent_diff
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      5.0
# 4                      NaN
#
# [5 rows x 50 columns]

# %%
# combine train and test data
all_data = pd.concat([train, test], ignore_index=True)
all_data.head()
# Out:
#    srch_id            date_time  site_id  visitor_location_country_id  \
# 0        1  2013-04-04 08:32:15       12                          187
# 1        1  2013-04-04 08:32:15       12                          187
# 2        1  2013-04-04 08:32:15       12                          187
# 3        1  2013-04-04 08:32:15       12                          187
# 4        1  2013-04-04 08:32:15       12                          187
#
#    visitor_hist_starrating  visitor_hist_adr_usd  prop_country_id  prop_id  \
# 0                      NaN                   NaN              219      893
# 1                      NaN                   NaN              219    10404
# 2                      NaN                   NaN              219    21315
# 3                      NaN                   NaN              219    27348
# 4                      NaN                   NaN              219    29604
#
#    prop_starrating  prop_review_score           ...             \
# 0                3                3.5           ...
# 1                4                4.0           ...
# 2                3                4.5           ...
# 3                2                4.0           ...
# 4                4                3.5           ...
#
#    comp5_rate_percent_diff  comp6_rate  comp6_inv  comp6_rate_percent_diff  \
# 0                      NaN         NaN        NaN                      NaN
# 1                      NaN         NaN        NaN                      NaN
# 2                      NaN         NaN        NaN                      NaN
# 3                      NaN         NaN        NaN                      NaN
# 4                      NaN         NaN        NaN                      NaN
#
#    comp7_rate  comp7_inv  comp7_rate_percent_diff  comp8_rate  comp8_inv  \
# 0         NaN        NaN                      NaN         0.0        0.0
# 1         NaN        NaN                      NaN         0.0        0.0
# 2         NaN        NaN                      NaN         0.0        0.0
# 3         NaN        NaN                      NaN        -1.0        0.0
# 4         NaN        NaN                      NaN         0.0        0.0
#
#    comp8_rate_percent_diff
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      5.0
# 4                      NaN
#
# [5 rows x 50 columns]

# %%
print('Whole dataset has %d records' % len(all_data))
# Out:
# Whole dataset has 16540159 records

# %%
all_data['date_time'] = pd.to_datetime(all_data.date_time)
all_data.sort_values(by=['date_time'],inplace=True)

# %%
all_data = all_data.reset_index(drop=True)
all_data.head()
# Out:
#    srch_id           date_time  site_id  visitor_location_country_id  \
# 0   365278 2012-11-01 00:01:37       24                          216
# 1   365278 2012-11-01 00:01:37       24                          216
# 2   365278 2012-11-01 00:01:37       24                          216
# 3   365278 2012-11-01 00:01:37       24                          216
# 4   365278 2012-11-01 00:01:37       24                          216
#
#    visitor_hist_starrating  visitor_hist_adr_usd  prop_country_id  prop_id  \
# 0                      NaN                   NaN              225    24202
# 1                      NaN                   NaN              225      327
# 2                      NaN                   NaN              225    20797
# 3                      NaN                   NaN              225    53733
# 4                      NaN                   NaN              225    57269
#
#    prop_starrating  prop_review_score           ...             \
# 0                3                0.0           ...
# 1                4                4.5           ...
# 2                3                3.0           ...
# 3                3                3.0           ...
# 4                4                4.5           ...
#
#    comp5_rate_percent_diff  comp6_rate  comp6_inv  comp6_rate_percent_diff  \
# 0                      NaN         NaN        NaN                      NaN
# 1                      7.0         NaN        NaN                      NaN
# 2                      NaN         NaN        NaN                      NaN
# 3                      NaN         NaN        NaN                      NaN
# 4                      2.0         NaN        NaN                      NaN
#
#    comp7_rate  comp7_inv  comp7_rate_percent_diff  comp8_rate  comp8_inv  \
# 0         NaN        NaN                      NaN         NaN        NaN
# 1         NaN        NaN                      NaN         NaN        NaN
# 2         NaN        NaN                      NaN         NaN        NaN
# 3         NaN        NaN                      NaN         NaN        NaN
# 4         NaN        NaN                      NaN         NaN        NaN
#
#    comp8_rate_percent_diff
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
#
# [5 rows x 50 columns]

# %% [markdown]
# <h4> Plot the median price trend:

# %%
df = all_data[['date_time','price_usd']]
df = df.set_index('date_time')
df = df.groupby(level=0).median()
print('df has: %d records'%len(df))

# select intervals data to plot & see price trend
# select 500 data points (one in 1304 points)

interval_range = len(df)//500  
mid_idx_lst = []
for i in range(1,501):
    mid_idx = (1304*(i-1) + 1304*i)//2
    mid_idx_lst.append(mid_idx)

df_sampled = df.iloc[mid_idx_lst]
df_sampled.plot()
# Out:
# df has: 652044 records
# 1304

# %% [markdown]
# <h4> Resample data:

# %%
# all_data.info()

# %%
all_data_resetIndex = all_data.set_index('date_time')
all_data_resetIndex.head()
# Out:
#                      srch_id  site_id  visitor_location_country_id  \
# date_time
# 2012-11-01 00:01:37   365278       24                          216
# 2012-11-01 00:01:37   365278       24                          216
# 2012-11-01 00:01:37   365278       24                          216
# 2012-11-01 00:01:37   365278       24                          216
# 2012-11-01 00:01:37   365278       24                          216
#
#                      visitor_hist_starrating  visitor_hist_adr_usd  \
# date_time
# 2012-11-01 00:01:37                      NaN                   NaN
# 2012-11-01 00:01:37                      NaN                   NaN
# 2012-11-01 00:01:37                      NaN                   NaN
# 2012-11-01 00:01:37                      NaN                   NaN
# 2012-11-01 00:01:37                      NaN                   NaN
#
#                      prop_country_id  prop_id  prop_starrating  \
# date_time
# 2012-11-01 00:01:37              225    24202                3
# 2012-11-01 00:01:37              225      327                4
# 2012-11-01 00:01:37              225    20797                3
# 2012-11-01 00:01:37              225    53733                3
# 2012-11-01 00:01:37              225    57269                4
#
#                      prop_review_score  prop_brand_bool  \
# date_time
# 2012-11-01 00:01:37                0.0                0
# 2012-11-01 00:01:37                4.5                0
# 2012-11-01 00:01:37                3.0                0
# 2012-11-01 00:01:37                3.0                0
# 2012-11-01 00:01:37                4.5                0
#
#                               ...             comp5_rate_percent_diff  \
# date_time                     ...
# 2012-11-01 00:01:37           ...                                 NaN
# 2012-11-01 00:01:37           ...                                 7.0
# 2012-11-01 00:01:37           ...                                 NaN
# 2012-11-01 00:01:37           ...                                 NaN
# 2012-11-01 00:01:37           ...                                 2.0
#
#                      comp6_rate  comp6_inv  comp6_rate_percent_diff  \
# date_time
# 2012-11-01 00:01:37         NaN        NaN                      NaN
# 2012-11-01 00:01:37         NaN        NaN                      NaN
# 2012-11-01 00:01:37         NaN        NaN                      NaN
# 2012-11-01 00:01:37         NaN        NaN                      NaN
# 2012-11-01 00:01:37         NaN        NaN                      NaN
#
#                      comp7_rate  comp7_inv  comp7_rate_percent_diff  \
# date_time
# 2012-11-01 00:01:37         NaN        NaN                      NaN
# 2012-11-01 00:01:37         NaN        NaN                      NaN
# 2012-11-01 00:01:37         NaN        NaN                      NaN
# 2012-11-01 00:01:37         NaN        NaN                      NaN
# 2012-11-01 00:01:37         NaN        NaN                      NaN
#
#                      comp8_rate  comp8_inv  comp8_rate_percent_diff
# date_time
# 2012-11-01 00:01:37         NaN        NaN                      NaN
# 2012-11-01 00:01:37         NaN        NaN                      NaN
# 2012-11-01 00:01:37         NaN        NaN                      NaN
# 2012-11-01 00:01:37         NaN        NaN                      NaN
# 2012-11-01 00:01:37         NaN        NaN                      NaN
#
# [5 rows x 49 columns]

# %%
weekly = all_data_resetIndex.resample('W').median()
print('there are %d weeks in total.'%len(weekly))
weekly.head()
# Out:
#              srch_id  site_id  visitor_location_country_id  \
# date_time
# 2012-11-04  333568.0      5.0                        219.0
# 2012-11-11  335665.0      5.0                        219.0
# 2012-11-18  329876.0      5.0                        219.0
# 2012-11-25  333585.0      5.0                        219.0
# 2012-12-02  334454.0      5.0                        219.0
#
#             visitor_hist_starrating  visitor_hist_adr_usd  prop_country_id  \
# date_time
# 2012-11-04                     3.31                142.71            219.0
# 2012-11-11                     3.33                145.84            219.0
# 2012-11-18                     3.33                143.78            219.0
# 2012-11-25                     3.50                152.61            219.0
# 2012-12-02                     3.33                150.54            219.0
#
#             prop_id  prop_starrating  prop_review_score  prop_brand_bool  \
# date_time
# 2012-11-04  69497.5              3.0                4.0              1.0
# 2012-11-11  69738.0              3.0                4.0              1.0
# 2012-11-18  69730.0              3.0                4.0              1.0
# 2012-11-25  69615.0              3.0                4.0              1.0
# 2012-12-02  69638.0              3.0                4.0              1.0
#
#                      ...             comp5_rate_percent_diff  comp6_rate  \
# date_time            ...
# 2012-11-04           ...                                12.0         0.0
# 2012-11-11           ...                                12.0         0.0
# 2012-11-18           ...                                12.0         0.0
# 2012-11-25           ...                                13.0         0.0
# 2012-12-02           ...                                13.0         0.0
#
#             comp6_inv  comp6_rate_percent_diff  comp7_rate  comp7_inv  \
# date_time
# 2012-11-04        0.0                     11.0         0.0        0.0
# 2012-11-11        0.0                     11.0         0.0        0.0
# 2012-11-18        0.0                     11.0         0.0        0.0
# 2012-11-25        0.0                     11.0         0.0        0.0
# 2012-12-02        0.0                     11.0         0.0        0.0
#
#             comp7_rate_percent_diff  comp8_rate  comp8_inv  \
# date_time
# 2012-11-04                     12.0         0.0        0.0
# 2012-11-11                     12.0         0.0        0.0
# 2012-11-18                     12.0         0.0        0.0
# 2012-11-25                     12.0         0.0        0.0
# 2012-12-02                     12.0         0.0        0.0
#
#             comp8_rate_percent_diff
# date_time
# 2012-11-04                     11.0
# 2012-11-11                     11.0
# 2012-11-18                     11.0
# 2012-11-25                     11.0
# 2012-12-02                     11.0
#
# [5 rows x 49 columns]

# %% [markdown]
# There are 35 weeks in total.

# %%
weekly[['price_usd']].plot()

# %% [markdown]
# Summer time is the popular time for traveling, which yields the increasing hotel price.

# %% [markdown]
# <h3> Split data into training, validation and test set

# %%
training_size_large = int(len(all_data) * 0.8)
validation_size = int(training_size_large * 0.2)
training_size = training_size_large - validation_size
test_size = int(len(all_data) * 0.2)

# %%
print('training size: %d'%training_size)
print('validation size: %d'%validation_size)
print('test size: %d'%test_size)
# Out:
# training size: 10585702
# validation size: 2646425
# test size: 3308031

# %%
# Approach1: split data manually
training_data = all_data[0: training_size]
validation_data = all_data[training_size:(training_size + validation_size)]
test_data = all_data[(training_size + validation_size): (training_size + validation_size + test_size)]

# %% [markdown]
# <h4> check dataset feats:

# %%
all_data.columns
# Out:
# Index(['srch_id', 'date_time', 'site_id', 'visitor_location_country_id',
#        'visitor_hist_starrating', 'visitor_hist_adr_usd', 'prop_country_id',
#        'prop_id', 'prop_starrating', 'prop_review_score', 'prop_brand_bool',
#        'prop_location_score1', 'prop_location_score2',
#        'prop_log_historical_price', 'price_usd', 'promotion_flag',
#        'srch_destination_id', 'srch_length_of_stay', 'srch_booking_window',
#        'srch_adults_count', 'srch_children_count', 'srch_room_count',
#        'srch_saturday_night_bool', 'srch_query_affinity_score',
#        'orig_destination_distance', 'random_bool', 'comp1_rate', 'comp1_inv',
#        'comp1_rate_percent_diff', 'comp2_rate', 'comp2_inv',
#        'comp2_rate_percent_diff', 'comp3_rate', 'comp3_inv',
#        'comp3_rate_percent_diff', 'comp4_rate', 'comp4_inv',
#        'comp4_rate_percent_diff', 'comp5_rate', 'comp5_inv',
#        'comp5_rate_percent_diff', 'comp6_rate', 'comp6_inv',
#        'comp6_rate_percent_diff', 'comp7_rate', 'comp7_inv',
#        'comp7_rate_percent_diff', 'comp8_rate', 'comp8_inv',
#        'comp8_rate_percent_diff'],
#       dtype='object')

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16540159 entries, 0 to 16540158
# Data columns (total 50 columns):
# srch_id                        int64
# date_time                      datetime64[ns]
# site_id                        int64
# visitor_location_country_id    int64
# visitor_hist_starrating        float64
# visitor_hist_adr_usd           float64
# prop_country_id                int64
# prop_id                        int64
# prop_starrating                int64
# prop_review_score              float64
# prop_brand_bool                int64
# prop_location_score1           float64
# prop_location_score2           float64
# prop_log_historical_price      float64
# price_usd                      float64
# promotion_flag                 int64
# srch_destination_id            int64
# srch_length_of_stay            int64
# srch_booking_window            int64
# srch_adults_count              int64
# srch_children_count            int64
# srch_room_count                int64
# srch_saturday_night_bool       int64
# srch_query_affinity_score      float64
# orig_destination_distance      float64
# random_bool                    int64
# comp1_rate                     float64
# comp1_inv                      float64
# comp1_rate_percent_diff        float64
# comp2_rate                     float64
# comp2_inv                      float64
# comp2_rate_percent_diff        float64
# comp3_rate                     float64
# comp3_inv                      float64
# comp3_rate_percent_diff        float64
# comp4_rate                     float64
# comp4_inv                      float64
# comp4_rate_percent_diff        float64
# comp5_rate                     float64
# comp5_inv                      float64
# comp5_rate_percent_diff        float64
# comp6_rate                     float64
# comp6_inv                      float64
# comp6_rate_percent_diff        float64
# comp7_rate                     float64
# comp7_inv                      float64
# comp7_rate_percent_diff        float64
# comp8_rate                     float64
# comp8_inv                      float64
# comp8_rate_percent_diff        float64
# dtypes: datetime64[ns](1), float64(33), int64(16)
# memory usage: 6.2 GB

# %% [markdown]
# <h3> Chi-2 test correlation of categorical feats:

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
from scipy.stats import chi2_contingency

class ChiSquare:
    def __init__(self, dataframe):
        self.df = dataframe
        self.p = None #P-Value
        self.chi2 = None #Chi Test Statistic
        self.dof = None
        
        self.dfTabular = None
        self.dfExpected = None
    
    def _print_chisquare_result(self, colX, alpha):
        result = ""
        if self.p<alpha:
            result="{0} is IMPORTANT for Prediction".format(colX)
        else:
            result="{0} is NOT an important predictor. (Discard {0} from model)".format(colX)

        print(result)
    
    
    def TestIndependence(self,colX,colY, alpha=0.05):
        X = self.df[colX].astype(str)
        Y = self.df[colY].astype(str)
        
        self.dfObserved = pd.crosstab(Y,X) 
        chi2, p, dof, expected = stats.chi2_contingency(self.dfObserved.values)
        self.p = p
        self.chi2 = chi2
        self.dof = dof 
        
        self.dfExpected = pd.DataFrame(expected, columns=self.dfObserved.columns, index = self.dfObserved.index)
        
        self._print_chisquare_result(colX, alpha)

# %% [markdown]
# Since the size of training set is still too large, I select the first 50000 records as training samples to test chi-square scores of categorical features and "price_usd":

# %%
# sampling training data
trainning_data_small = training_data[:50000]

# %%
#Initialize ChiSquare Class
cT = ChiSquare(trainning_data_small)

# Feature Selection
testColumns = ['srch_id', 'site_id', 'visitor_location_country_id', 'prop_country_id', 'prop_id', 'srch_destination_id']
for var in testColumns:
    cT.TestIndependence(colX=var,colY="price_usd" )
# Out:
# srch_id is IMPORTANT for Prediction
# site_id is IMPORTANT for Prediction
# visitor_location_country_id is IMPORTANT for Prediction
# prop_country_id is IMPORTANT for Prediction
# prop_id is IMPORTANT for Prediction
# srch_destination_id is IMPORTANT for Prediction

# %% [markdown]
# <h4> Interpretation: </h4>
#
# The results show that all categorical variables are important for prediction based on Chi-squared test. We should incorporate these categorical features into our final prediction model.
